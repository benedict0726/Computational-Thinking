# %% [markdown]
# <a href="https://colab.research.google.com/github/benedict0726/Computational-Thinking/blob/master/Week6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hellow World")
# Out:
# Hellow World

# %%
print("How are you")
# Out:
# How are you
