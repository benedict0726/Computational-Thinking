# %% [markdown]
# <a href="https://colab.research.google.com/github/benedict0726/Computational-Thinking/blob/master/%E7%94%98%E5%BA%AD%E9%8A%A8_Week11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 習題解答:報告分組

# %%
# 方法(一):商數
## Input
number = input("Enter your seat number?")
number = int(number)
## Process
group = (number - 1) // 5
## Output
print("Group is", group)
# Out:
# Enter your seat number?+19
# Group is 3

# %%
number = input("Enter your number")
number = int(number)
group = (number - 1) // 5 + 1
print ("group is", group)
# Out:
# Enter your number19
# group is 4
