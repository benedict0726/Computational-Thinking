# %% [markdown]
# <a href="https://colab.research.google.com/github/benedict0726/Computational-Thinking/blob/master/week11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("哈囉,大家好。我叫Zyxo64,是一個聊天機器人。")
hobby = "我很喜歡美食東西,也喜歡養動物。今天很高興有機會來到世新大學,請大家多多指教。"
print( hobby )
name = input("嗨!妳好,請問大名?: ")
print("我叫", name)
print("你好", name, "很高興認識你")
year = input("請問一下今年是西元2020年,那是民國幾年呢? ")
print("對!應該沒錯,謝謝妳!")
myage = int(input("再猜猜看我今年幾歲? "))
print("哇!你好聰明,我今年的確", myage)
nyears = 100 - myage
print("我再", nyears, "年就滿100歲了。")
print("到時候是西元", int(year) + nyears + 1911, "年")
print("我喜歡巧克力,也喜歡嘗試各種新食物。")
food = input("你呢。你最喜歡的食物是什麼?: ")
print("我也喜歡", food)
question = "你多久吃一次" + food + "?: "
howoften = input(question)
print("真有趣。不知道這樣對健康好不好!")
animal = input("我最喜歡的動物是長頸鹿。你呢?; ")
print("我不喜歡", animal)
print("不知道", animal, "喜不喜歡吃", food, "?")
feeling = input("你今天心情如何?; ")
print("告訴我你現在", feeling, "的原因。 ")
reason = input("為什麼: ")
print("我知道了。謝謝分享。")
print("今天事情真多!我累了,下次再聊。")
print("再見", name, "我喜歡跟你聊天!")
# Out:
# 哈囉,大家好。我叫Zyxo64,是一個聊天機器人。
# 我很喜歡美食東西,也喜歡養動物。今天很高興有機會來到世新大學,請大家多多指教。
# 嗨!妳好,請問大名?: 阿甘
# 我叫 阿甘
# 你好 阿甘 很高興認識你
# 請問一下今年是西元2020年,那是民國幾年呢? 109
# 對!應該沒錯,謝謝妳!
# 再猜猜看我今年幾歲? 50
# 哇!你好聰明,我今年的確 50
# 我再 50 年就滿100歲了。
# 到時候是西元 2070 年
# 我喜歡巧克力,也喜歡嘗試各種新食物。
# 你呢。你最喜歡的食物是什麼?: 巧克力
# 我也喜歡 巧克力
# 你多久吃一次巧克力?: 每天
# 真有趣。不知道這樣對健康好不好!
# 我最喜歡的動物是長頸鹿。你呢?; 也是
# 我不喜歡 也是
# 不知道 也是 喜不喜歡吃 巧克力 ?
# 你今天心情如何?; 還好
# 告訴我你現在 還好 的原因。
# 為什麼: 沒為什麼
# 我知道了。謝謝分享。
# 今天事情真多!我累了,下次再聊。
# 再見 阿甘 我喜歡跟你聊天!
